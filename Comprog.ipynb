# %%
import sys
print("System Check: PASSED")
print(f"Running on: {sys.version}")
# Out:
# System Check: PASSED
# Running on: 3.13.7 (tags/v3.13.7:bcee1c3, Aug 14 2025, 14:15:11) [MSC v.1944 64 bit (AMD64)]
